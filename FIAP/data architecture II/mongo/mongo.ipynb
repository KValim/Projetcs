# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('mongodb+srv://KValim:OI8rvd07t5HdQWed@cluster0.47qozmb.mongodb.net/test')

# %%
for db in client.list_databases():
    print(db)
# Out:
# {'name': 'labfiap', 'sizeOnDisk': 40960, 'empty': False}
# {'name': 'mongodbVSCodePlaygroundDB', 'sizeOnDisk': 40960, 'empty': False}
# {'name': 'sample_airbnb', 'sizeOnDisk': 54890496, 'empty': False}
# {'name': 'sample_analytics', 'sizeOnDisk': 9584640, 'empty': False}
# {'name': 'sample_geospatial', 'sizeOnDisk': 2543616, 'empty': False}
# {'name': 'sample_guides', 'sizeOnDisk': 40960, 'empty': False}
# {'name': 'sample_mflix', 'sizeOnDisk': 50495488, 'empty': False}
# {'name': 'sample_restaurants', 'sizeOnDisk': 9957376, 'empty': False}
# {'name': 'sample_supplies', 'sizeOnDisk': 1261568, 'empty': False}
# {'name': 'sample_training', 'sizeOnDisk': 56905728, 'empty': False}
# {'name': 'sample_weatherdata', 'sizeOnDisk': 2904064, 'empty': False}
# {'name': 'test', 'sizeOnDisk': 12288, 'empty': False}
# {'name': 'admin', 'sizeOnDisk': 294912, 'empty': False}
# {'name': 'local', 'sizeOnDisk': 3684687872, 'empty': False}

# %%
db = client["sample_supplies"]
db
# Out:
# Database(MongoClient(host=['ac-jscmb1c-shard-00-01.47qozmb.mongodb.net:27017', 'ac-jscmb1c-shard-00-02.47qozmb.mongodb.net:27017', 'ac-jscmb1c-shard-00-00.47qozmb.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-ar3aze-shard-0', tls=True), 'sample_supplies')

# %%
db.list_collection_names()
# Out:
# ['sales', 'contador']

# %%
sales = db['sales']
sales
# Out:
# Collection(Database(MongoClient(host=['ac-jscmb1c-shard-00-01.47qozmb.mongodb.net:27017', 'ac-jscmb1c-shard-00-02.47qozmb.mongodb.net:27017', 'ac-jscmb1c-shard-00-00.47qozmb.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-ar3aze-shard-0', tls=True), 'sample_supplies'), 'sales')

# %%
import pandas as pd

# Get the "sales" collection
collection = db['sales']

# Use find method to retrieve all the documents
cursor = collection.find({})

# Create a DataFrame from the cursor
df = pd.DataFrame(list(cursor))

df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 5001                       100 2023-01-24 01:00:51.216
# 5002  63cf2dd24cdf860c2f4a1d27                     NaT
# 5003  63cf2dd24cdf860c2f4a1d28                     NaT
# 5004  63cf2e454cdf860c2f4a1d29                     NaT
# 5005  63cf32698626cd24bd3500d8                     NaT
#
#                                                   items storeLocation  \
# 0     [{'name': 'printer paper', 'tags': ['office', ...        Denver
# 1     [{'name': 'envelopes', 'tags': ['stationary', ...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %%
from pandas.io.json import json_normalize

cursor = collection.find({})
df = json_normalize(list(cursor))

df
# Out:
# C:\Users\KAIQUEHENRIQUEVALIM\AppData\Local\Temp\ipykernel_13072\1378505633.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(list(cursor))
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 5001                       100 2023-01-24 01:00:51.216
# 5002  63cf2dd24cdf860c2f4a1d27                     NaT
# 5003  63cf2dd24cdf860c2f4a1d28                     NaT
# 5004  63cf2e454cdf860c2f4a1d29                     NaT
# 5005  63cf32698626cd24bd3500d8                     NaT
#
#                                                   items storeLocation  \
# ...

# %%
import flatten_json

# Get the "sales" collection
collection = db['sales']

# Use find method to retrieve all the documents
cursor = collection.find({})

# Create a list to hold the flat dictionaries
flattened_docs = []

# Iterate through the cursor and convert each document to a flat dictionary
for doc in cursor:
    flatten_doc = flatten_json.flatten(doc)
    flattened_docs.append(flatten_doc)

# Create a DataFrame from the list of flat dictionaries
df = pd.DataFrame(flattened_docs)

df
# Out:
#                            _id                saleDate   items_0_name  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506  printer paper
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918      envelopes
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185        notepad
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343         binder
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253       backpack
# ...                        ...                     ...            ...
# 5001                       100 2023-01-24 01:00:51.216        notepad
# 5002  63cf2dd24cdf860c2f4a1d27                     NaT            NaN
# 5003  63cf2dd24cdf860c2f4a1d28                     NaT            NaN
# 5004  63cf2e454cdf860c2f4a1d29                     NaT            NaN
# 5005  63cf32698626cd24bd3500d8                     NaT            NaN
#
#      items_0_tags_0 items_0_tags_1 items_0_price  items_0_quantity  \
# ...

# %%
x = df.saleDate
df.columns
# Out:
# Index(['_id', 'saleDate', 'items_0_name', 'items_0_tags_0', 'items_0_tags_1',
#        'items_0_price', 'items_0_quantity', 'items_1_name', 'items_1_tags_0',
#        'items_1_tags_1', 'items_1_tags_2', 'items_1_price', 'items_1_quantity',
#        'items_2_name', 'items_2_tags_0', 'items_2_tags_1', 'items_2_tags_2',
#        'items_2_tags_3', 'items_2_price', 'items_2_quantity', 'items_3_name',
#        'items_3_tags_0', 'items_3_tags_1', 'items_3_tags_2', 'items_3_price',
#        'items_3_quantity', 'items_4_name', 'items_4_tags_0', 'items_4_tags_1',
#        'items_4_tags_2', 'items_4_price', 'items_4_quantity', 'items_5_name',
#        'items_5_tags_0', 'items_5_tags_1', 'items_5_tags_2', 'items_5_price',
#        'items_5_quantity', 'items_6_name', 'items_6_tags_0', 'items_6_tags_1',
#        'items_6_tags_2', 'items_6_price', 'items_6_quantity', 'items_7_name',
#        'items_7_tags_0', 'items_7_tags_1', 'items_7_tags_2', 'items_7_price',
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig = go.Figure()
fig.add_trace(go.Box(   y=df['customer_age'],
                        name='customer_age'))
fig.add_trace(go.Box(   y=df['items_quantity'],
                        name='items_quantity'))
fig.add_trace(go.Box(   y=df['customer_satisfaction'],
                        name='customer_satisfaction'))
fig.update_layout(height=600)
fig.show()
